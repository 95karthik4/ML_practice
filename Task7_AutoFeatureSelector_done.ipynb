# %% [markdown]
# # Task 7: AutoFeatureSelector Tool
# ## This task is to test your understanding of various Feature Selection methods outlined in the lecture and the ability to apply this knowledge in a real-world dataset to select best features and also to build an automated feature selection tool as your toolkit
#
# ### Use your knowledge of different feature selector methods to build an Automatic Feature Selection tool
# - Pearson Correlation
# - Chi-Square
# - RFE
# - Embedded
# - Tree (Random Forest)
# - Tree (Light GBM)

# %% [markdown]
# ### Dataset: FIFA 19 Player Skills
# #### Attributes: FIFA 2019 players attributes like Age, Nationality, Overall, Potential, Club, Value, Wage, Preferred Foot, International Reputation, Weak Foot, Skill Moves, Work Rate, Position, Jersey Number, Joined, Loaned From, Contract Valid Until, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, Heading, Accuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, and Release Clause.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
from collections import Counter
import math
from scipy import stats

# %%
player_df = pd.read_csv("fifa19.csv")

# %%
numcols = ['Overall', 'Crossing','Finishing',  'ShortPassing',  'Dribbling','LongPassing', 'BallControl', 'Acceleration','SprintSpeed', 'Agility',  'Stamina','Volleys','FKAccuracy','Reactions','Balance','ShotPower','Strength','LongShots','Aggression','Interceptions']
catcols = ['Preferred Foot','Position','Body Type','Nationality','Weak Foot']

# %%
player_df = player_df[numcols+catcols]

# %%
traindf = pd.concat([player_df[numcols], pd.get_dummies(player_df[catcols])],axis=1)
features = traindf.columns

traindf = traindf.dropna()

# %%
traindf = pd.DataFrame(traindf,columns=features)

# %%
y = traindf['Overall']>=87
X = traindf.copy()
del X['Overall']

# %%
X.head()
# Out:
#    Crossing  Finishing  ShortPassing  Dribbling  LongPassing  BallControl  \
# 0      84.0       95.0          90.0       97.0         87.0         96.0
# 1      84.0       94.0          81.0       88.0         77.0         94.0
# 2      79.0       87.0          84.0       96.0         78.0         95.0
# 3      17.0       13.0          50.0       18.0         51.0         42.0
# 4      93.0       82.0          92.0       86.0         91.0         91.0
#
#    Acceleration  SprintSpeed  Agility  Stamina  ...  Nationality_Uganda  \
# 0          91.0         86.0     91.0     72.0  ...               False
# 1          89.0         91.0     87.0     88.0  ...               False
# 2          94.0         90.0     96.0     81.0  ...               False
# 3          57.0         58.0     60.0     43.0  ...               False
# 4          78.0         76.0     79.0     90.0  ...               False
#
#    Nationality_Ukraine  Nationality_United Arab Emirates  \
# 0                False                             False
# 1                False                             False
# 2                False                             False
# 3                False                             False
# 4                False                             False
#
#    Nationality_United States  Nationality_Uruguay  Nationality_Uzbekistan  \
# 0                      False                False                   False
# 1                      False                False                   False
# 2                      False                False                   False
# 3                      False                False                   False
# 4                      False                False                   False
#
#    Nationality_Venezuela  Nationality_Wales  Nationality_Zambia  \
# 0                  False              False               False
# 1                  False              False               False
# 2                  False              False               False
# 3                  False              False               False
# 4                  False              False               False
#
#    Nationality_Zimbabwe
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 223 columns]

# %%
len(X.columns)
# Out:
# 223

# %% [markdown]
# ### Set some fixed set of features

# %%
feature_name = list(X.columns)
# no of maximum features we need to select
num_feats=30

# %% [markdown]
# ## Filter Feature Selection - Pearson Correlation

# %% [markdown]
# ### Pearson Correlation function

# %%
def cor_selector(X, y, num_feats):
    cor_list = []
    for col in X.columns:
        cor = np.corrcoef(X[col], y)[0, 1]
        if np.isnan(cor):
            cor = 0
        cor_list.append(cor)
    cor_list = [abs(i) for i in cor_list]

    cor_support = [False] * len(cor_list)
    cor_feature = X.iloc[:, np.argsort(cor_list)[-num_feats:]].columns.tolist()
    for i in np.argsort(cor_list)[-num_feats:]:
        cor_support[i] = True

    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y,num_feats)
print(str(len(cor_feature)), 'selected features')
# Out:
# 30 selected features

# %% [markdown]
# ### List the selected features from Pearson Correlation

# %%
cor_feature
# Out:
# ['Nationality_Costa Rica',
#  'Position_LAM',
#  'Nationality_Uruguay',
#  'Acceleration',
#  'SprintSpeed',
#  'Strength',
#  'Nationality_Gabon',
#  'Nationality_Slovenia',
#  'Stamina',
#  'Weak Foot',
#  'Agility',
#  'Crossing',
#  'Nationality_Belgium',
#  'Dribbling',
#  'ShotPower',
#  'LongShots',
#  'Finishing',
#  'BallControl',
#  'FKAccuracy',
#  'LongPassing',
#  'Volleys',
#  'ShortPassing',
#  'Position_RF',
#  'Position_LF',
#  'Body Type_PLAYER_BODY_TYPE_25',
#  'Body Type_Courtois',
#  'Body Type_Neymar',
#  'Body Type_Messi',
#  'Body Type_C. Ronaldo',
#  'Reactions']

# %% [markdown]
# ## Filter Feature Selection - Chi-Sqaure

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Chi-Squared Selector function

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import SelectKBest, chi2

def chi_squared_selector(X, y, num_feats):
    X_norm = X.copy().fillna(0)
    X_norm = MinMaxScaler().fit_transform(X_norm)

    k = min(num_feats, X_norm.shape[1])

    chi_selector = SelectKBest(score_func=chi2, k=k)
    chi_selector.fit(X_norm, y)

    chi_support = chi_selector.get_support()
    chi_feature = X.columns[chi_support].tolist()

    return chi_support, chi_feature

# %%
chi_support, chi_feature = chi_squared_selector(X, y,num_feats)
print(str(len(chi_feature)), 'selected features')
# Out:
# 30 selected features

# %% [markdown]
# ### List the selected features from Chi-Square

# %%
chi_feature
# Out:
# ['Finishing',
#  'ShortPassing',
#  'LongPassing',
#  'BallControl',
#  'Volleys',
#  'FKAccuracy',
#  'Reactions',
#  'LongShots',
#  'Position_CM',
#  'Position_LAM',
#  'Position_LF',
#  'Position_LW',
#  'Position_RB',
#  'Position_RF',
#  'Body Type_C. Ronaldo',
#  'Body Type_Courtois',
#  'Body Type_Messi',
#  'Body Type_Neymar',
#  'Body Type_PLAYER_BODY_TYPE_25',
#  'Nationality_Belgium',
#  'Nationality_Costa Rica',
#  'Nationality_Croatia',
#  'Nationality_Egypt',
#  'Nationality_England',
#  'Nationality_France',
#  'Nationality_Gabon',
#  'Nationality_Slovakia',
#  'Nationality_Slovenia',
#  'Nationality_Spain',
#  'Nationality_Uruguay']

# %% [markdown]
# ## Wrapper Feature Selection - Recursive Feature Elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### RFE Selector function

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

def rfe_selector(X, y, num_feats):
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    model = LogisticRegression(max_iter=5000, solver="liblinear")
    rfe = RFE(estimator=model, n_features_to_select=min(num_feats, X.shape[1]))
    rfe.fit(X_scaled, y)

    rfe_support = rfe.get_support()
    rfe_feature = X.columns[rfe_support].tolist()

    return rfe_support, rfe_feature

# %%
rfe_support, rfe_feature = rfe_selector(X, y,num_feats)
print(str(len(rfe_feature)), 'selected features')
# Out:
# 30 selected features

# %% [markdown]
# ### List the selected features from RFE

# %%
rfe_feature
# Out:
# ['Crossing',
#  'Finishing',
#  'ShortPassing',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Stamina',
#  'FKAccuracy',
#  'Reactions',
#  'Strength',
#  'Aggression',
#  'Position_CAM',
#  'Position_CB',
#  'Position_CF',
#  'Position_CM',
#  'Position_GK',
#  'Position_LCB',
#  'Position_LM',
#  'Position_RB',
#  'Position_RCB',
#  'Position_RM',
#  'Position_RW',
#  'Body Type_Lean',
#  'Nationality_China PR',
#  'Nationality_Netherlands',
#  'Nationality_Portugal',
#  'Nationality_Saudi Arabia',
#  'Nationality_Switzerland']

# %% [markdown]
# ## Embedded Selection - Lasso: SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler

# %%
def embedded_log_reg_selector(X, y, num_feats):
    model = LogisticRegression(penalty="l1", solver="liblinear", max_iter=500)
    selector = SelectFromModel(model, max_features=num_feats)
    selector.fit(X, y)
    embedded_lr_support = selector.get_support()
    embedded_lr_feature = X.loc[:, embedded_lr_support].columns.tolist()
    return embedded_lr_support, embedded_lr_feature

# %%
embedded_lr_support, embedded_lr_feature = embedded_log_reg_selector(X, y, num_feats)
print(str(len(embedded_lr_feature)), 'selected features')
# Out:
# 30 selected features

# %%
embedded_lr_feature
# Out:
# ['Crossing',
#  'Finishing',
#  'Dribbling',
#  'LongPassing',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'FKAccuracy',
#  'Reactions',
#  'Balance',
#  'Aggression',
#  'Interceptions',
#  'Weak Foot',
#  'Preferred Foot_Right',
#  'Position_CAM',
#  'Position_CM',
#  'Position_LCB',
#  'Position_LM',
#  'Position_LW',
#  'Position_RB',
#  'Position_RW',
#  'Body Type_Lean',
#  'Nationality_Brazil',
#  'Nationality_Croatia',
#  'Nationality_England',
#  'Nationality_France',
#  'Nationality_Germany',
#  'Nationality_Italy',
#  'Nationality_Netherlands',
#  'Nationality_Uruguay']

# %% [markdown]
# ## Tree based(Random Forest): SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

# %%
def embedded_rf_selector(X, y, num_feats):
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    selector = SelectFromModel(model, max_features=num_feats)
    selector.fit(X, y)
    embedded_rf_support = selector.get_support()
    embedded_rf_feature = X.loc[:, embedded_rf_support].columns.tolist()
    return embedded_rf_support, embedded_rf_feature

# %%
embedder_rf_support, embedder_rf_feature = embedded_rf_selector(X, y, num_feats)
print(str(len(embedder_rf_feature)), 'selected features')
# Out:
# 24 selected features

# %%
embedder_rf_feature
# Out:
# ['Crossing',
#  'Finishing',
#  'ShortPassing',
#  'Dribbling',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Stamina',
#  'Volleys',
#  'FKAccuracy',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Weak Foot',
#  'Preferred Foot_Right',
#  'Body Type_Courtois',
#  'Body Type_Normal',
#  'Nationality_Slovenia']

# %% [markdown]
# ## Tree based(Light GBM): SelectFromModel

# %%
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

# %%
def embedded_lgbm_selector(X, y, num_feats):

    model = LGBMClassifier(n_estimators=200, random_state=42)

    selector = SelectFromModel(model, max_features=num_feats)
    selector.fit(X, y)
    embedded_lgbm_support = selector.get_support()
    embedded_lgbm_feature = X.loc[:, embedded_lgbm_support].columns.tolist()
    return embedded_lgbm_support, embedded_lgbm_feature

# %%
embedded_lgbm_support, embedded_lgbm_feature = embedded_lgbm_selector(X, y, num_feats)
print(str(len(embedded_lgbm_feature)), 'selected features')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 55, number of negative: 18104
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001108 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1812
# [LightGBM] [Info] Number of data points in the train set: 18159, number of used features: 124
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003029 -> initscore=-5.796555
# [LightGBM] [Info] Start training from score -5.796555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 23 selected features

# %%
embedded_lgbm_feature
# Out:
# ['Crossing',
#  'Finishing',
#  'ShortPassing',
#  'Dribbling',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Stamina',
#  'Volleys',
#  'FKAccuracy',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Position_LCB',
#  'Body Type_Lean',
#  'Nationality_France',
#  'Nationality_Italy']

# %% [markdown]
# ## Putting all of it together: AutoFeatureSelector Tool

# %%
pd.set_option('display.max_rows', None)

# Put all selection together
feature_selection_df = pd.DataFrame({
    'Feature': feature_name,
    'Pearson': cor_support,
    'Chi-2': chi_support,
    'RFE': rfe_support,
    'Logistics': embedded_lr_support,      
    'Random Forest': embedder_rf_support, 
    'LightGBM': embedded_lgbm_support      
})

# Count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df.drop(columns=['Feature']), axis=1)

# Sort by Total
feature_selection_df = feature_selection_df.sort_values(['Total', 'Feature'], ascending=[False, True])
feature_selection_df.reset_index(drop=True, inplace=True)

feature_selection_df
# Out:
#                               Feature  Pearson  Chi-2    RFE  Logistics  \
# 0                          FKAccuracy     True   True   True       True
# 1                           Finishing     True   True   True       True
# 2                         LongPassing     True   True   True       True
# 3                           Reactions     True   True   True       True
# 4                        Acceleration     True  False   True       True
# 5                             Agility     True  False   True       True
# 6                         BallControl     True   True   True      False
# 7                            Crossing     True  False   True       True
# 8                        ShortPassing     True   True   True      False
# 9                         SprintSpeed     True  False   True       True
# 10                         Aggression    False  False   True       True
# 11                          Dribbling     True  False  False       True
# 12                          LongShots     True   True  False      False
# 13                            Stamina     True  False   True      False
# 14                           Strength     True  False   True      False
# 15                            Volleys     True   True  False      False
# 16                            Balance    False  False  False       True
# 17                 Body Type_Courtois     True   True  False      False
# 18                     Body Type_Lean    False  False   True       True
# 19                      Interceptions    False  False  False       True
# 20                 Nationality_France    False   True  False       True
# 21               Nationality_Slovenia     True   True  False      False
# 22                Nationality_Uruguay     True   True  False       True
# 23                        Position_CM    False   True   True       True
# 24                       Position_LCB    False  False   True       True
# 25                        Position_RB    False   True   True       True
# 26                          ShotPower     True  False  False      False
# 27                          Weak Foot     True  False  False       True
# 28               Body Type_C. Ronaldo     True   True  False      False
# 29                    Body Type_Messi     True   True  False      False
# 30                   Body Type_Neymar     True   True  False      False
# 31      Body Type_PLAYER_BODY_TYPE_25     True   True  False      False
# 32                Nationality_Belgium     True   True  False      False
# 33             Nationality_Costa Rica     True   True  False      False
# 34                Nationality_Croatia    False   True  False       True
# 35                Nationality_England    False   True  False       True
# 36                  Nationality_Gabon     True   True  False      False
# 37                  Nationality_Italy    False  False  False       True
# 38            Nationality_Netherlands    False  False   True       True
# 39                       Position_CAM    False  False   True       True
# 40                       Position_LAM     True   True  False      False
# 41                        Position_LF     True   True  False      False
# 42                        Position_LM    False  False   True       True
# 43                        Position_LW    False   True  False       True
# 44                        Position_RF     True   True  False      False
# 45                        Position_RW    False  False   True       True
# 46               Preferred Foot_Right    False  False  False       True
# 47                   Body Type_Normal    False  False  False      False
# 48                 Nationality_Brazil    False  False  False       True
# 49               Nationality_China PR    False  False   True      False
# 50                  Nationality_Egypt    False   True  False      False
# 51                Nationality_Germany    False  False  False       True
# 52               Nationality_Portugal    False  False   True      False
# 53           Nationality_Saudi Arabia    False  False   True      False
# 54               Nationality_Slovakia    False   True  False      False
# 55                  Nationality_Spain    False   True  False      False
# 56            Nationality_Switzerland    False  False   True      False
# 57                        Position_CB    False  False   True      False
# 58                        Position_CF    False  False   True      False
# 59                        Position_GK    False  False   True      False
# 60                       Position_RCB    False  False   True      False
# 61                        Position_RM    False  False   True      False
# 62                Body Type_Akinfenwa    False  False  False      False
# 63                  Body Type_Shaqiri    False  False  False      False
# 64                   Body Type_Stocky    False  False  False      False
# 65            Nationality_Afghanistan    False  False  False      False
# 66                Nationality_Albania    False  False  False      False
# 67                Nationality_Algeria    False  False  False      False
# 68                Nationality_Andorra    False  False  False      False
# 69                 Nationality_Angola    False  False  False      False
# 70      Nationality_Antigua & Barbuda    False  False  False      False
# 71              Nationality_Argentina    False  False  False      False
# 72                Nationality_Armenia    False  False  False      False
# 73              Nationality_Australia    False  False  False      False
# 74                Nationality_Austria    False  False  False      False
# 75             Nationality_Azerbaijan    False  False  False      False
# 76               Nationality_Barbados    False  False  False      False
# 77                Nationality_Belarus    False  False  False      False
# 78                 Nationality_Belize    False  False  False      False
# 79                  Nationality_Benin    False  False  False      False
# 80                Nationality_Bermuda    False  False  False      False
# 81                Nationality_Bolivia    False  False  False      False
# 82     Nationality_Bosnia Herzegovina    False  False  False      False
# 83               Nationality_Botswana    False  False  False      False
# 84               Nationality_Bulgaria    False  False  False      False
# 85           Nationality_Burkina Faso    False  False  False      False
# 86                Nationality_Burundi    False  False  False      False
# 87               Nationality_Cameroon    False  False  False      False
# 88                 Nationality_Canada    False  False  False      False
# 89             Nationality_Cape Verde    False  False  False      False
# 90   Nationality_Central African Rep.    False  False  False      False
# 91                   Nationality_Chad    False  False  False      False
# 92                  Nationality_Chile    False  False  False      False
# 93               Nationality_Colombia    False  False  False      False
# 94                Nationality_Comoros    False  False  False      False
# 95                  Nationality_Congo    False  False  False      False
# 96                   Nationality_Cuba    False  False  False      False
# 97                Nationality_Curacao    False  False  False      False
# 98                 Nationality_Cyprus    False  False  False      False
# 99         Nationality_Czech Republic    False  False  False      False
# 100              Nationality_DR Congo    False  False  False      False
# 101               Nationality_Denmark    False  False  False      False
# 102    Nationality_Dominican Republic    False  False  False      False
# 103               Nationality_Ecuador    False  False  False      False
# 104           Nationality_El Salvador    False  False  False      False
# 105     Nationality_Equatorial Guinea    False  False  False      False
# 106               Nationality_Eritrea    False  False  False      False
# 107               Nationality_Estonia    False  False  False      False
# 108              Nationality_Ethiopia    False  False  False      False
# 109         Nationality_FYR Macedonia    False  False  False      False
# 110         Nationality_Faroe Islands    False  False  False      False
# 111                  Nationality_Fiji    False  False  False      False
# 112               Nationality_Finland    False  False  False      False
# 113                Nationality_Gambia    False  False  False      False
# 114               Nationality_Georgia    False  False  False      False
# 115                 Nationality_Ghana    False  False  False      False
# 116                Nationality_Greece    False  False  False      False
# 117               Nationality_Grenada    False  False  False      False
# 118                  Nationality_Guam    False  False  False      False
# 119             Nationality_Guatemala    False  False  False      False
# 120                Nationality_Guinea    False  False  False      False
# 121         Nationality_Guinea Bissau    False  False  False      False
# 122                Nationality_Guyana    False  False  False      False
# 123                 Nationality_Haiti    False  False  False      False
# 124              Nationality_Honduras    False  False  False      False
# 125             Nationality_Hong Kong    False  False  False      False
# 126               Nationality_Hungary    False  False  False      False
# 194   Nationality_São Tomé & Príncipe    False  False  False      False
# 195              Nationality_Tanzania    False  False  False      False
# 196              Nationality_Thailand    False  False  False      False
# 197                  Nationality_Togo    False  False  False      False
# 198     Nationality_Trinidad & Tobago    False  False  False      False
# 199               Nationality_Tunisia    False  False  False      False
# 200                Nationality_Turkey    False  False  False      False
# 201                Nationality_Uganda    False  False  False      False
# 202               Nationality_Ukraine    False  False  False      False
# 203  Nationality_United Arab Emirates    False  False  False      False
# 204         Nationality_United States    False  False  False      False
# 205            Nationality_Uzbekistan    False  False  False      False
# 206             Nationality_Venezuela    False  False  False      False
# 207                 Nationality_Wales    False  False  False      False
# 208                Nationality_Zambia    False  False  False      False
# 209              Nationality_Zimbabwe    False  False  False      False
# 210                      Position_CDM    False  False  False      False
# 211                       Position_LB    False  False  False      False
# 212                      Position_LCM    False  False  False      False
# 213                      Position_LDM    False  False  False      False
# 214                       Position_LS    False  False  False      False
# 215                      Position_LWB    False  False  False      False
# 216                      Position_RAM    False  False  False      False
# 217                      Position_RCM    False  False  False      False
# 218                      Position_RDM    False  False  False      False
# 219                       Position_RS    False  False  False      False
# 220                      Position_RWB    False  False  False      False
# 221                       Position_ST    False  False  False      False
# 222               Preferred Foot_Left    False  False  False      False
#
#      Random Forest  LightGBM  Total
# 0             True      True      6
# 1             True      True      6
# 2             True      True      6
# 3             True      True      6
# 4             True      True      5
# 5             True      True      5
# 6             True      True      5
# 7             True      True      5
# 8             True      True      5
# 9             True      True      5
# 10            True      True      4
# 11            True      True      4
# 12            True      True      4
# 13            True      True      4
# 14            True      True      4
# 15            True      True      4
# 16            True      True      3
# 17            True     False      3
# 18           False      True      3
# 19            True      True      3
# 20           False      True      3
# 21            True     False      3
# 22           False     False      3
# 23           False     False      3
# 24           False      True      3
# 25           False     False      3
# 26            True      True      3
# 27            True     False      3
# 28           False     False      2
# 29           False     False      2
# 30           False     False      2
# 31           False     False      2
# 32           False     False      2
# 33           False     False      2
# 34           False     False      2
# 35           False     False      2
# 36           False     False      2
# 37           False      True      2
# 38           False     False      2
# 39           False     False      2
# 40           False     False      2
# 41           False     False      2
# 42           False     False      2
# 43           False     False      2
# 44           False     False      2
# 45           False     False      2
# 46            True     False      2
# 47            True     False      1
# 48           False     False      1
# 49           False     False      1
# 50           False     False      1
# 51           False     False      1
# 52           False     False      1
# 53           False     False      1
# 54           False     False      1
# 55           False     False      1
# 56           False     False      1
# 57           False     False      1
# 58           False     False      1
# 59           False     False      1
# 60           False     False      1
# 61           False     False      1
# 62           False     False      0
# 63           False     False      0
# 64           False     False      0
# 65           False     False      0
# 66           False     False      0
# 67           False     False      0
# 68           False     False      0
# 69           False     False      0
# 70           False     False      0
# 71           False     False      0
# 72           False     False      0
# 73           False     False      0
# 74           False     False      0
# 75           False     False      0
# 76           False     False      0
# 77           False     False      0
# 78           False     False      0
# 79           False     False      0
# 80           False     False      0
# 81           False     False      0
# 82           False     False      0
# 83           False     False      0
# 84           False     False      0
# 85           False     False      0
# 86           False     False      0
# 87           False     False      0
               'FKAccuracy','Reactions','Balance','ShotPower','Strength','LongShots',
               'Aggression','Interceptions']
    catcols = ['Preferred Foot','Position','Body Type','Nationality','Weak Foot']

    player_df = player_df[numcols+catcols]

    traindf = pd.concat([player_df[numcols], pd.get_dummies(player_df[catcols])], axis=1)
    traindf = traindf.dropna()
    features = traindf.columns
    traindf = pd.DataFrame(traindf, columns=features)

    y = traindf['Overall'] >= 87
    X = traindf.copy()
    del X['Overall']

    num_feats = 30
    return X, y, num_feats

# %%
def autoFeatureSelector(dataset_path, methods, num_feats=20):
    import pandas as pd
    import numpy as np

    # Use your preprocessing function to get data
    X, y, default_num_feats = preprocess_dataset(dataset_path)

    # If user didn’t specify num_feats, fall back to preprocess default
    if num_feats is None:
        num_feats = default_num_feats

    feature_name = X.columns
    results = {}

    # Run each method requested
    if 'pearson' in methods:
        cor_support, cor_feature = cor_selector(X, y, num_feats)
        results['Pearson'] = cor_support
    if 'chi-square' in methods:
        chi_support, chi_feature = chi_squared_selector(X, y, num_feats)
        results['Chi-2'] = chi_support
    if 'rfe' in methods:
        rfe_support, rfe_feature = rfe_selector(X, y, num_feats)
        results['RFE'] = rfe_support
    if 'log-reg' in methods:
    
        lr_support, lr_feature = embedded_log_reg_selector(X, y, num_feats)
        results['Logistic'] = lr_support
    if 'rf' in methods:
        rf_support, rf_feature = embedded_rf_selector(X, y, num_feats)
        results['Random Forest'] = rf_support
    if 'lgbm' in methods:
        lgbm_support, lgbm_feature = embedded_lgbm_selector(X, y, num_feats)
        results['LightGBM'] = lgbm_support

    # Combine into DataFrame
    feature_selection_df = pd.DataFrame({'Feature': feature_name})
    for method, support in results.items():
        feature_selection_df[method] = support

    # Count how many times a feature was selected
    feature_selection_df['Total'] = np.sum(
        feature_selection_df.drop(columns=['Feature']), axis=1
    )
    feature_selection_df = feature_selection_df.sort_values(
        ['Total', 'Feature'], ascending=[False, True]
    ).reset_index(drop=True)

    # Best features are those selected at least once
    best_features = feature_selection_df[
        feature_selection_df['Total'] > 0
    ]['Feature'].tolist()

    return best_features, feature_selection_df

# %%
best_features, summary = autoFeatureSelector(
    dataset_path="fifa19.csv",
    methods=['pearson', 'chi-square', 'rfe', 'log-reg', 'rf', 'lgbm'],
    num_feats=30
)

print("Best features selected:", best_features)
summary
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 55, number of negative: 18104
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000775 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1812
# [LightGBM] [Info] Number of data points in the train set: 18159, number of used features: 124
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.003029 -> initscore=-5.796555
# [LightGBM] [Info] Start training from score -5.796555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best features selected: ['FKAccuracy', 'Finishing', 'LongPassing', 'Reactions', 'Acceleration', 'Agility', 'BallControl', 'Crossing', 'ShortPassing', 'SprintSpeed', 'Aggression', 'Dribbling', 'LongShots', 'Stamina', 'Strength', 'Volleys', 'Balance', 'Body Type_Courtois', 'Body Type_Lean', 'Interceptions', 'Nationality_France', 'Nationality_Slovenia', 'Nationality_Uruguay', 'Position_CM', 'Position_LCB', 'Position_RB', 'ShotPower', 'Weak Foot', 'Body Type_C. Ronaldo', 'Body Type_Messi', 'Body Type_Neymar', 'Body Type_PLAYER_BODY_TYPE_25', 'Nationality_Belgium', 'Nationality_Costa Rica', 'Nationality_Croatia', 'Nationality_England', 'Nationality_Gabon', 'Nationality_Italy', 'Nationality_Netherlands', 'Position_CAM', 'Position_LAM', 'Position_LF', 'Position_LM', 'Position_LW', 'Position_RF', 'Position_RW', 'Preferred Foot_Right', 'Body Type_Normal', 'Nationality_Brazil', 'Nationality_China PR', 'Nationality_Egypt', 'Nationality_Germany', 'Nationality_Portugal', 'Nationality_Saudi Arabia', 'Nationality_Slovakia', 'Nationality_Spain', 'Nationality_Switzerland', 'Position_CB', 'Position_CF', 'Position_GK', 'Position_RCB', 'Position_RM']
#                               Feature  Pearson  Chi-2    RFE  Logistic  \
# 0                          FKAccuracy     True   True   True      True
# 1                           Finishing     True   True   True      True
# 2                         LongPassing     True   True   True      True
# 3                           Reactions     True   True   True      True
# 4                        Acceleration     True  False   True      True
# 5                             Agility     True  False   True      True
# 6                         BallControl     True   True   True     False
# 7                            Crossing     True  False   True      True
# 8                        ShortPassing     True   True   True     False
# 9                         SprintSpeed     True  False   True      True
# 10                         Aggression    False  False   True      True
# 11                          Dribbling     True  False  False      True
# 12                          LongShots     True   True  False     False
# 13                            Stamina     True  False   True     False
# 14                           Strength     True  False   True     False
# 15                            Volleys     True   True  False     False
# 16                            Balance    False  False  False      True
# 17                 Body Type_Courtois     True   True  False     False
# 18                     Body Type_Lean    False  False   True      True
# 19                      Interceptions    False  False  False      True
# 20                 Nationality_France    False   True  False      True
# 21               Nationality_Slovenia     True   True  False     False
# 22                Nationality_Uruguay     True   True  False      True
# 23                        Position_CM    False   True   True      True
# 24                       Position_LCB    False  False   True      True
# 25                        Position_RB    False   True   True      True
# 26                          ShotPower     True  False  False     False
# 27                          Weak Foot     True  False  False      True
# 28               Body Type_C. Ronaldo     True   True  False     False
# 29                    Body Type_Messi     True   True  False     False
# 30                   Body Type_Neymar     True   True  False     False
# 31      Body Type_PLAYER_BODY_TYPE_25     True   True  False     False
# 32                Nationality_Belgium     True   True  False     False
# 33             Nationality_Costa Rica     True   True  False     False
# 34                Nationality_Croatia    False   True  False      True
# 35                Nationality_England    False   True  False      True
# 36                  Nationality_Gabon     True   True  False     False
# 37                  Nationality_Italy    False  False  False      True
# 38            Nationality_Netherlands    False  False   True      True
# 39                       Position_CAM    False  False   True      True
# 40                       Position_LAM     True   True  False     False
# 41                        Position_LF     True   True  False     False
# 42                        Position_LM    False  False   True      True
# 43                        Position_LW    False   True  False      True
# 44                        Position_RF     True   True  False     False
# 45                        Position_RW    False  False   True      True
# 46               Preferred Foot_Right    False  False  False      True
# 47                   Body Type_Normal    False  False  False     False
# 48                 Nationality_Brazil    False  False  False      True
# 49               Nationality_China PR    False  False   True     False
# 50                  Nationality_Egypt    False   True  False     False
# 51                Nationality_Germany    False  False  False      True
# 52               Nationality_Portugal    False  False   True     False
# 53           Nationality_Saudi Arabia    False  False   True     False
# 54               Nationality_Slovakia    False   True  False     False
# 55                  Nationality_Spain    False   True  False     False
# 56            Nationality_Switzerland    False  False   True     False
# 57                        Position_CB    False  False   True     False
# 58                        Position_CF    False  False   True     False
# 59                        Position_GK    False  False   True     False
# 60                       Position_RCB    False  False   True     False
# 61                        Position_RM    False  False   True     False
# 62                Body Type_Akinfenwa    False  False  False     False
# 63                  Body Type_Shaqiri    False  False  False     False
# 64                   Body Type_Stocky    False  False  False     False
# 65            Nationality_Afghanistan    False  False  False     False
# 66                Nationality_Albania    False  False  False     False
# 67                Nationality_Algeria    False  False  False     False
# 68                Nationality_Andorra    False  False  False     False
# 69                 Nationality_Angola    False  False  False     False
# 70      Nationality_Antigua & Barbuda    False  False  False     False
# 71              Nationality_Argentina    False  False  False     False
# 72                Nationality_Armenia    False  False  False     False
# 73              Nationality_Australia    False  False  False     False
# 74                Nationality_Austria    False  False  False     False
# 75             Nationality_Azerbaijan    False  False  False     False
# 76               Nationality_Barbados    False  False  False     False
# 77                Nationality_Belarus    False  False  False     False
# 78                 Nationality_Belize    False  False  False     False
# 79                  Nationality_Benin    False  False  False     False
# 80                Nationality_Bermuda    False  False  False     False
# 81                Nationality_Bolivia    False  False  False     False
# 82     Nationality_Bosnia Herzegovina    False  False  False     False
# 83               Nationality_Botswana    False  False  False     False
# 84               Nationality_Bulgaria    False  False  False     False
# 85           Nationality_Burkina Faso    False  False  False     False
# 86                Nationality_Burundi    False  False  False     False
# 87               Nationality_Cameroon    False  False  False     False
# 88                 Nationality_Canada    False  False  False     False
# 89             Nationality_Cape Verde    False  False  False     False
# 90   Nationality_Central African Rep.    False  False  False     False
# 91                   Nationality_Chad    False  False  False     False
# 92                  Nationality_Chile    False  False  False     False
# 93               Nationality_Colombia    False  False  False     False
# 94                Nationality_Comoros    False  False  False     False
# 95                  Nationality_Congo    False  False  False     False
# 96                   Nationality_Cuba    False  False  False     False
# 97                Nationality_Curacao    False  False  False     False
# 98                 Nationality_Cyprus    False  False  False     False
# 99         Nationality_Czech Republic    False  False  False     False
# 100              Nationality_DR Congo    False  False  False     False
# 101               Nationality_Denmark    False  False  False     False
# 102    Nationality_Dominican Republic    False  False  False     False
# 103               Nationality_Ecuador    False  False  False     False
# 104           Nationality_El Salvador    False  False  False     False
# 105     Nationality_Equatorial Guinea    False  False  False     False
# 106               Nationality_Eritrea    False  False  False     False
# 107               Nationality_Estonia    False  False  False     False
# 108              Nationality_Ethiopia    False  False  False     False
# 109         Nationality_FYR Macedonia    False  False  False     False
# 110         Nationality_Faroe Islands    False  False  False     False
# 111                  Nationality_Fiji    False  False  False     False
# 112               Nationality_Finland    False  False  False     False
# 113                Nationality_Gambia    False  False  False     False
# 114               Nationality_Georgia    False  False  False     False
# 115                 Nationality_Ghana    False  False  False     False
# 116                Nationality_Greece    False  False  False     False
# 117               Nationality_Grenada    False  False  False     False
# 118                  Nationality_Guam    False  False  False     False
# 119             Nationality_Guatemala    False  False  False     False
# 120                Nationality_Guinea    False  False  False     False
# 121         Nationality_Guinea Bissau    False  False  False     False
# 122                Nationality_Guyana    False  False  False     False
# 123                 Nationality_Haiti    False  False  False     False
# 124              Nationality_Honduras    False  False  False     False
# 125             Nationality_Hong Kong    False  False  False     False
# 126               Nationality_Hungary    False  False  False     False
# 127               Nationality_Iceland    False  False  False     False
# 128                 Nationality_India    False  False  False     False
# 129             Nationality_Indonesia    False  False  False     False
# 130                  Nationality_Iran    False  False  False     False
# 131                  Nationality_Iraq    False  False  False     False
# 132                Nationality_Israel    False  False  False     False
# 133           Nationality_Ivory Coast    False  False  False     False
# 134               Nationality_Jamaica    False  False  False     False
# 135                 Nationality_Japan    False  False  False     False
# 136                Nationality_Jordan    False  False  False     False
# 137            Nationality_Kazakhstan    False  False  False     False
# 138                 Nationality_Kenya    False  False  False     False
# 139             Nationality_Korea DPR    False  False  False     False
# 140        Nationality_Korea Republic    False  False  False     False
# 141                Nationality_Kosovo    False  False  False     False
# 142                Nationality_Kuwait    False  False  False     False
# 143                Nationality_Latvia    False  False  False     False
# 144               Nationality_Lebanon    False  False  False     False
# 145               Nationality_Liberia    False  False  False     False
# 146                 Nationality_Libya    False  False  False     False
# 147         Nationality_Liechtenstein    False  False  False     False
# 148             Nationality_Lithuania    False  False  False     False
# 149            Nationality_Luxembourg    False  False  False     False
# 150            Nationality_Madagascar    False  False  False     False
# 151                  Nationality_Mali    False  False  False     False
# 152                 Nationality_Malta    False  False  False     False
# 153            Nationality_Mauritania    False  False  False     False
# 154             Nationality_Mauritius    False  False  False     False
# 155                Nationality_Mexico    False  False  False     False
# 156               Nationality_Moldova    False  False  False     False
# 157            Nationality_Montenegro    False  False  False     False
# 158            Nationality_Montserrat    False  False  False     False
# 159               Nationality_Morocco    False  False  False     False
# 160            Nationality_Mozambique    False  False  False     False
# 161               Nationality_Namibia    False  False  False     False
# 162         Nationality_New Caledonia    False  False  False     False
# 163           Nationality_New Zealand    False  False  False     False
# 164             Nationality_Nicaragua    False  False  False     False
# 165                 Nationality_Niger    False  False  False     False
# 166               Nationality_Nigeria    False  False  False     False
# 167      Nationality_Northern Ireland    False  False  False     False
# 168                Nationality_Norway    False  False  False     False
# 169                  Nationality_Oman    False  False  False     False
# 170             Nationality_Palestine    False  False  False     False
# 171                Nationality_Panama    False  False  False     False
# 172              Nationality_Paraguay    False  False  False     False
# 173                  Nationality_Peru    False  False  False     False
# 174           Nationality_Philippines    False  False  False     False
# 175                Nationality_Poland    False  False  False     False
# 176           Nationality_Puerto Rico    False  False  False     False
# 177                 Nationality_Qatar    False  False  False     False
# 178   Nationality_Republic of Ireland    False  False  False     False
# 179               Nationality_Romania    False  False  False     False
# 180                Nationality_Russia    False  False  False     False
# 181                Nationality_Rwanda    False  False  False     False
# 182              Nationality_Scotland    False  False  False     False
# 183               Nationality_Senegal    False  False  False     False
# 184                Nationality_Serbia    False  False  False     False
# 185          Nationality_Sierra Leone    False  False  False     False
# 186          Nationality_South Africa    False  False  False     False
# 187           Nationality_South Sudan    False  False  False     False
# 188        Nationality_St Kitts Nevis    False  False  False     False
# 189              Nationality_St Lucia    False  False  False     False
# 190                 Nationality_Sudan    False  False  False     False
# 191              Nationality_Suriname    False  False  False     False
# 192                Nationality_Sweden    False  False  False     False
# 193                 Nationality_Syria    False  False  False     False
# 194   Nationality_São Tomé & Príncipe    False  False  False     False
# 195              Nationality_Tanzania    False  False  False     False
# 196              Nationality_Thailand    False  False  False     False
# 197                  Nationality_Togo    False  False  False     False
# 198     Nationality_Trinidad & Tobago    False  False  False     False
# 199               Nationality_Tunisia    False  False  False     False
# 200                Nationality_Turkey    False  False  False     False
# 201                Nationality_Uganda    False  False  False     False
# 202               Nationality_Ukraine    False  False  False     False
# 203  Nationality_United Arab Emirates    False  False  False     False
# 204         Nationality_United States    False  False  False     False
# 205            Nationality_Uzbekistan    False  False  False     False
# 206             Nationality_Venezuela    False  False  False     False
# 207                 Nationality_Wales    False  False  False     False
# 208                Nationality_Zambia    False  False  False     False
# 209              Nationality_Zimbabwe    False  False  False     False
# 210                      Position_CDM    False  False  False     False
# 211                       Position_LB    False  False  False     False
# 212                      Position_LCM    False  False  False     False
# 213                      Position_LDM    False  False  False     False
# 214                       Position_LS    False  False  False     False
# 215                      Position_LWB    False  False  False     False
# 216                      Position_RAM    False  False  False     False
# 217                      Position_RCM    False  False  False     False
# 218                      Position_RDM    False  False  False     False
# 219                       Position_RS    False  False  False     False
# 220                      Position_RWB    False  False  False     False
# 221                       Position_ST    False  False  False     False
# 222               Preferred Foot_Left    False  False  False     False
#
#      Random Forest  LightGBM  Total
# 0             True      True      6
# 1             True      True      6
# 2             True      True      6
# 3             True      True      6
# 4             True      True      5
# 5             True      True      5
# 6             True      True      5
# 7             True      True      5
# 8             True      True      5
# 9             True      True      5
# 10            True      True      4
# 11            True      True      4
# 12            True      True      4
# 13            True      True      4
# 14            True      True      4
# 15            True      True      4
# 16            True      True      3
# 17            True     False      3
# 18           False      True      3
# 19            True      True      3
# 20           False      True      3
# 21            True     False      3
# 22           False     False      3
# 23           False     False      3
# 24           False      True      3
# 25           False     False      3
# 26            True      True      3
# 27            True     False      3
# 28           False     False      2
# 29           False     False      2
# 30           False     False      2
# 31           False     False      2
# 32           False     False      2
# 33           False     False      2
# 34           False     False      2
# 35           False     False      2
# 36           False     False      2
# 37           False      True      2
# 38           False     False      2
# 39           False     False      2
# 40           False     False      2
# 41           False     False      2
# 42           False     False      2
# 43           False     False      2
# 44           False     False      2
# 45           False     False      2
# 46            True     False      2
# 47            True     False      1
# 48           False     False      1
# 49           False     False      1
# 50           False     False      1
# 51           False     False      1
# 52           False     False      1
# 53           False     False      1
# 54           False     False      1
# 55           False     False      1
# 56           False     False      1
# 57           False     False      1
# 58           False     False      1
# 59           False     False      1
# 60           False     False      1
# 61           False     False      1
# 62           False     False      0
# 63           False     False      0
# 64           False     False      0
# 65           False     False      0
# 66           False     False      0
# 67           False     False      0
# 68           False     False      0
# 69           False     False      0
# 70           False     False      0
# 71           False     False      0
# 72           False     False      0
# 73           False     False      0
# 74           False     False      0
# 75           False     False      0
